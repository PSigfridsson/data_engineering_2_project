# %%
import requests
import os
import json
import time


username = 'psigfridsson'
token = os.environ.get("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")

# %%
response = requests.get('https://api.github.com/orgs/octokit/repos', auth=(username, token))
print(response.json())
# Out:
# [{'id': 417862, 'node_id': 'MDEwOlJlcG9zaXRvcnk0MTc4NjI=', 'name': 'octokit.rb', 'full_name': 'octokit/octokit.rb', 'private': False, 'owner': {'login': 'octokit', 'id': 3430433, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MzA0MzM=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3430433?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/octokit', 'html_url': 'https://github.com/octokit', 'followers_url': 'https://api.github.com/users/octokit/followers', 'following_url': 'https://api.github.com/users/octokit/following{/other_user}', 'gists_url': 'https://api.github.com/users/octokit/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/octokit/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/octokit/subscriptions', 'organizations_url': 'https://api.github.com/users/octokit/orgs', 'repos_url': 'https://api.github.com/users/octokit/repos', 'events_url': 'https://api.github.com/users/octokit/events{/privacy}', 'received_events_url': 'https:
# ...

# %%
response1 = requests.get('https://api.github.com/repos/octokit/octokit.rb/commits?per_page=1&sha=4-stable', auth=(username, token))
print(response1.links)
#print(response1.json())
#print(len(response1.json()))

with open('data.txt', 'w') as outfile:
    json.dump(response1.json(), outfile)
# Out:
# {'next': {'url': 'https://api.github.com/repositories/417862/commits?per_page=1&sha=4-stable&page=2', 'rel': 'next'}, 'last': {'url': 'https://api.github.com/repositories/417862/commits?per_page=1&sha=4-stable&page=2968', 'rel': 'last'}}

# %%
import re
# u = creator, r = repository
def commitCount(u, r):
  return re.search('\d+$', requests.get('https://api.github.com/repos/{}/{}/commits?per_page=1'.format(u, r)).links['last']['url']).group()

print(commitCount(u="octokit", r="octokit.rb"))
# Out:
# 2968

# %%
repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-05-14"', auth=(username, token))
print(repo.json())
# Out:
# {'total_count': 202300, 'incomplete_results': False, 'items': [{'id': 13491895, 'node_id': 'MDEwOlJlcG9zaXRvcnkxMzQ5MTg5NQ==', 'name': 'free-programming-books', 'full_name': 'EbookFoundation/free-programming-books', 'private': False, 'owner': {'login': 'EbookFoundation', 'id': 14127308, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0MTI3MzA4', 'avatar_url': 'https://avatars.githubusercontent.com/u/14127308?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/EbookFoundation', 'html_url': 'https://github.com/EbookFoundation', 'followers_url': 'https://api.github.com/users/EbookFoundation/followers', 'following_url': 'https://api.github.com/users/EbookFoundation/following{/other_user}', 'gists_url': 'https://api.github.com/users/EbookFoundation/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/EbookFoundation/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/EbookFoundation/subscriptions', 'organizations_url': 'https://api.github.com/users/EbookFoun
# ...

# %%
print(len(repo.json()['items']))
# Out:
# 30

# %%
repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-05-14"&per_page=100', auth=(username, token))
print(len(repo.json()['items']))
print(repo.json())
# Out:
# 100
# ...

# %%
repo_items = []
repo_full = []

for i in range(1,11):
    repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-05-14"&per_page=100&page={}'.format(i), auth=(username, token))
    repo_items.append(repo.json()['items'])
    for j in repo.json()['items']:
        repo_full.append(j)
        
print(len(repo_items))
print(len(repo_full))
# Out:
# 10
# 1000

# %%
repo.json()['items']
# Out:
# [{'id': 108758373,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDg3NTgzNzM=',
#   'name': 'pipeline',
#   'full_name': 'banzaicloud/pipeline',
#   'private': False,
#   'owner': {'login': 'banzaicloud',
#    'id': 32848483,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMyODQ4NDgz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32848483?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/banzaicloud',
#    'html_url': 'https://github.com/banzaicloud',
#    'followers_url': 'https://api.github.com/users/banzaicloud/followers',
#    'following_url': 'https://api.github.com/users/banzaicloud/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/banzaicloud/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/banzaicloud/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/banzaicloud/subscriptions',
#    'organizations_url': 'https://api.github.com/users/banzaicloud/orgs',
# ...

# %%
repo_items = []
repo_full = []

for date in [1]:
    for i in range(1,11):
        repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2020-01-0{}"&per_page=100&page={}'.format(date, i), auth=(username, token))
        #print(repo.json()['items'])
print(len(repo.json()))
print(type(repo.json()))
        #repo_items.append(repo.json()['items'])
        #for j in repo.json()['items']:
         #   repo_full.append(j)
    #time.sleep(60)
        
#print(len(repo_items))
#print(len(repo_full))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9287c80ba6b4> in <module>
#       4 for date in [1]:
#       5     for i in range(1,11):
# ----> 6         repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2020-01-0{}"&per_page=100&page={}'.format(date, i), auth=(username, token))
#       7         #print(repo.json()['items'])
#       8 print(len(repo.json()))
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...

# %%
repo_items = []
repo_full = []

for month in range(1,13):
    for date in range(1,32):
        if month>=1 and month<=9:
            if date>=1 and date<=9:
                for page in range(1,11):
                    repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-0{}-0{}"&per_page=100&page={}'.format(month, date, page), auth=(username, token))
                    #print(repo.json())
                    repo_items.append(repo.json()['items'])
                    for j in repo.json()['items']:
                        repo_full.append(j)
                time.sleep(60)
            if date>=10:
                for page in range(1,11):
                    repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-0{}-{}"&per_page=100&page={}'.format(month, date, page), auth=(username, token))
                    repo_items.append(repo.json()['items'])
                    for j in repo.json()['items']:
                        repo_full.append(j)
                time.sleep(60)
        if month>=10:
            if date>=1 and date<=9:
                for page in range(1,11):
                    repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-{}-0{}"&per_page=100&page={}'.format(month, date, page), auth=(username, token))
                    repo_items.append(repo.json()['items'])
                    for j in repo.json()['items']:
                        repo_full.append(j)
                time.sleep(60)
            if date>=10:
                for page in range(1,11):
                    repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-{}-{}"&per_page=100&page={}'.format(month, date, page), auth=(username, token))
                    repo_items.append(repo.json()['items'])
                    for j in repo.json()['items']:
                        repo_full.append(j)
                time.sleep(60)


print(len(repo_items))
print(len(repo_full))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-67d97547429e> in <module>
#       9                     repo = requests.get('https://api.github.com/search/repositories?q=pushed:"2021-0{}-0{}"&per_page=100&page={}'.format(month, date, page), auth=(username, token))
#      10                     #print(repo.json())
# ---> 11                     repo_items.append(repo.json()['items'])
#      12                     for j in repo.json()['items']:
#      13                         repo_full.append(j)
#
# KeyError: 'items'
